# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('XLab.csv')

# %%
df = pd.read_csv('NewXlab.csv')

# %%
df1
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"America/De...
# 2                                  2021-03-29 10:59:08
# 3                                  2021-03-30 11:40:55
# 4                                  2021-03-30 13:11:05
# ..                                                 ...
# 376                                2021-04-07 20:24:34
# 377                                2021-04-08 10:42:11
# 378                                2021-04-08 20:28:39
# 379                                2021-04-07 18:44:56
# 380                                2021-04-09 12:12:41
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# ...

# %% [markdown]
# # 2.17 40.1 - 63.1

# %%
print(df.columns.tolist())
# Out:
# ['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress', 'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId', 'RecipientLastName', 'RecipientFirstName', 'RecipientEmail', 'ExternalReference', 'LocationLatitude', 'LocationLongitude', 'DistributionChannel', 'UserLanguage', 'Q2.1', 'Q2.2', 'Q2.2_6_TEXT', 'Q2.3', 'Q2.4', 'Q2.4_7_TEXT', 'Q2.5', 'Q2.6', 'Q2.7', 'Q2.8', 'Q2.10', 'Q2.9', 'Q2.11', 'Q2.12', 'Q2.13', 'Q2.14', 'Q2.15', 'Q2.16', 'Q2.16_3_TEXT', 'Q2.16_8_TEXT', 'Q2.17', 'Q2.18_1', 'Q2.18_2', 'Q2.19', 'Q4.1_First Click', 'Q4.1_Last Click', 'Q4.1_Page Submit', 'Q4.1_Click Count', 'Q4.3_First Click', 'Q4.3_Last Click', 'Q4.3_Page Submit', 'Q4.3_Click Count', 'Q4.4', 'Q4.5', 'Q4.7_1', 'Q4.7_2', 'Q4.7_3', 'Q4.7_4', 'Q4.7_5', 'Q4.7_6', 'Q4.7_7', 'Q4.8_1', 'Q4.8_2', 'Q4.8_3', 'Q4.8_4', 'Q4.8_5', 'Q4.8_6', 'Q4.9_1', 'Q4.9_2', 'Q4.9_3', 'Q4.9_4', 'Q5.1_First Click', 'Q5.1_Last Click', 'Q5.1_Page Submit', 'Q5.1_Click Count', 'Q5.2', 'Q5.2_16_TEXT', 'Q5.3', 'Q5.4', 'Q5.4_9_T
# ...

# %%
df = df[['Q2.17','Q40.1', 'Q41.1', 'Q42.1', 'Q43.1', 'Q44.1', 'Q45.1', 'Q46.1', 'Q47.1', 'Q48.1', 'Q49.1', 'Q50.1', 'Q51.1', 'Q52.1', 'Q53.1', 'Q54.1', 'Q55.1', 'Q56.1', 'Q57.1', 'Q58.1', 'Q59.1', 'Q60.1', 'Q61.1', 'Q62.1', 'Q63.1']]

# %%
df
# Out:
#                                                  Q2.17  \
# 0    When you purchase books, what format do you mo...
# 1                                {"ImportId":"QID200"}
# 2                                                  NaN
# 3                                                  NaN
# 4                               I don't purchase books
# ..                                                 ...
# 376                               I buy physical books
# 377                             I don't purchase books
# 378                                                NaN
# 379                               I buy physical books
# 380                               I buy physical books
#
#                                        Q40.1  \
# 0    Choose Your Favorite of the Books Below
# 1                      {"ImportId":"QID187"}
# 2                                        NaN
# 3                                        NaN
# 4                                          1
# ...

# %%
df = df.drop([0, 1])

# %%
# book_covariate = Q2.17,

#     ChRegCol = Q40.1,
#     ChRegBW = Q41.1,
#     ChSmCol = Q42.1,
#     ChSmBW = Q43.1,
#     ChNoCol = Q44.1,
#     ChNoBW = Q45.1,
    
#     FiRegCol = Q46.1,
#     FiRegBW = Q47.1,
#     FiSmCol = Q48.1,
#     FiSmBW = Q49.1,
#     FiNoCol = Q50.1,
#     FiNoBW = Q51.1,
    
#     NoRegCol = Q52.1,
#     NoRegBW = Q53.1,
#     NoSmCol = Q54.1,
#     NoSmBW = Q55.1,
#     NoNoCol = Q56.1,
#     NoNoBW = Q57.1,
    
#     ClRegCol = Q58.1,
#     ClRegBW = Q59.1,
#     ClSmCol = Q60.1,
#     ClSmBW = Q61.1,
#     ClNoCol = Q62.1,
#     ClNoBW = Q63.1

# %%
a = df['Q46.1'].unique()
b = df['Q47.1'].unique()
c = df['Q48.1'].unique()

# %%
a
# Out:
# array([nan, 'IM_cC15sUM3wdS0qGO', 'IM_79BIls9ITEeLEy2',
#        'IM_bCxbEb2KEjRiSAm'], dtype=object)

# %%
b
# Out:
# array([nan, 'IM_bCxbEb2KEjRiSAm', 'IM_79BIls9ITEeLEy2',
#        'IM_4YZShV208PsmCMu'], dtype=object)

# %%
c
# Out:
# array([nan, 'IM_79BIls9ITEeLEy2', 'IM_bpXACllyeiwpR78',
#        'IM_bCxbEb2KEjRiSAm'], dtype=object)

# %%
q_list = ['Q40.1', 'Q41.1', 'Q42.1', 'Q43.1', 'Q44.1', 'Q45.1', 'Q46.1', 'Q47.1', 'Q48.1', 'Q49.1', 'Q50.1', 'Q51.1', 'Q52.1', 'Q53.1', 'Q54.1', 'Q55.1', 'Q56.1', 'Q57.1', 'Q58.1', 'Q59.1', 'Q60.1', 'Q61.1', 'Q62.1', 'Q63.1']

# %%
for i in q_list:
    a = df[i].value_counts(normalize=True)
    print(a)
# Out:
# 3    0.407407
# 2    0.314815
# 1    0.277778
# Name: Q40.1, dtype: float64
# 1    0.396226
# 3    0.320755
# 2    0.283019
# Name: Q41.1, dtype: float64
# 3    0.436364
# 2    0.400000
# 1    0.163636
# Name: Q42.1, dtype: float64
# 1    0.436364
# 2    0.327273
# 3    0.236364
# Name: Q43.1, dtype: float64
# 3    0.388889
# 1    0.314815
# 2    0.296296
# Name: Q44.1, dtype: float64
# 3    0.370370
# 1    0.333333
# 2    0.296296
# Name: Q45.1, dtype: float64
# IM_79BIls9ITEeLEy2    0.490566
# IM_cC15sUM3wdS0qGO    0.377358
# IM_bCxbEb2KEjRiSAm    0.132075
# Name: Q46.1, dtype: float64
# IM_79BIls9ITEeLEy2    0.490909
# IM_4YZShV208PsmCMu    0.327273
# IM_bCxbEb2KEjRiSAm    0.181818
# Name: Q47.1, dtype: float64
# IM_bpXACllyeiwpR78    0.509091
# IM_79BIls9ITEeLEy2    0.418182
# IM_bCxbEb2KEjRiSAm    0.072727
# Name: Q48.1, dtype: float64
# IM_79BIls9ITEeLEy2    0.444444
# IM_5C1focehBmaxTiS    0.444444
# IM_bCxbEb2KEjRiSAm    0.111111
# Name: Q49.1, dtype: float64
# ...

# %%
# IM_79BIls9ITEeLEy2
# IM_bCxbEb2KEjRiSAm

# IM_0rzZZl5rKnoVR1s  
# IM_6tfBdi8rc1h4SN0

# IM_9o7tEXHqbcH8CrQ
# IM_eQJuiJHm3FKuXmS

# %%
for i in q_list:
    df[i] = df[i].replace('IM_79BIls9ITEeLEy2',1)
    df[i] = df[i].replace('IM_bCxbEb2KEjRiSAm',3)
    
    df[i] =df[i].replace('IM_0rzZZl5rKnoVR1s',1)
    df[i] =df[i].replace('IM_6tfBdi8rc1h4SN0',3)
    
    df[i] =df[i].replace('IM_9o7tEXHqbcH8CrQ',1)
    df[i] =df[i].replace('IM_eQJuiJHm3FKuXmS',3)

# %%
df
# Out:
#                       Q2.17 Q40.1 Q41.1 Q42.1 Q43.1 Q44.1 Q45.1  \
# 2                       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                       NaN   NaN   NaN   NaN     1   NaN   NaN
# 4    I don't purchase books     1   NaN   NaN   NaN   NaN   NaN
# 5              I buy ebooks   NaN   NaN   NaN   NaN   NaN   NaN
# 6                I buy both   NaN   NaN     3   NaN   NaN   NaN
# ..                      ...   ...   ...   ...   ...   ...   ...
# 376    I buy physical books   NaN   NaN   NaN   NaN   NaN   NaN
# 377  I don't purchase books   NaN   NaN   NaN   NaN   NaN   NaN
# 378                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 379    I buy physical books   NaN   NaN   NaN   NaN   NaN   NaN
# 380    I buy physical books   NaN   NaN   NaN   NaN   NaN   NaN
#
#                   Q46.1 Q47.1 Q48.1  ... Q54.1 Q55.1 Q56.1 Q57.1 Q58.1 Q59.1  \
# 2                   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
for i in q_list:
    a = df[i].value_counts(normalize=True)
    print(a)
# Out:
# 3    0.407407
# 2    0.314815
# 1    0.277778
# Name: Q40.1, dtype: float64
# 1    0.396226
# 3    0.320755
# 2    0.283019
# Name: Q41.1, dtype: float64
# 3    0.436364
# 2    0.400000
# 1    0.163636
# Name: Q42.1, dtype: float64
# 1    0.436364
# 2    0.327273
# 3    0.236364
# Name: Q43.1, dtype: float64
# 3    0.388889
# 1    0.314815
# 2    0.296296
# Name: Q44.1, dtype: float64
# 3    0.370370
# 1    0.333333
# 2    0.296296
# Name: Q45.1, dtype: float64
# 1                     0.490566
# IM_cC15sUM3wdS0qGO    0.377358
# 3                     0.132075
# Name: Q46.1, dtype: float64
# 1                     0.490909
# IM_4YZShV208PsmCMu    0.327273
# 3                     0.181818
# Name: Q47.1, dtype: float64
# IM_bpXACllyeiwpR78    0.509091
# 1                     0.418182
# 3                     0.072727
# Name: Q48.1, dtype: float64
# IM_5C1focehBmaxTiS    0.444444
# 1                     0.444444
# 3                     0.111111
# Name: Q49.1, dtype: float64
# ...

# %%
for i in q_list:
    print(df[i].unique())
# Out:
# [nan '1' '3' '2']
# [nan '2' '1' '3']
# [nan '3' '1' '2']
# [nan '1' '2' '3']
# [nan '1' '3' '2']
# [nan '2' '3' '1']
# [nan 'IM_cC15sUM3wdS0qGO' 1 3]
# [nan 3 1 'IM_4YZShV208PsmCMu']
# [nan 1 'IM_bpXACllyeiwpR78' 3]
# [nan 3 1 'IM_5C1focehBmaxTiS']
# [nan 3 'IM_3VIIMJClBmsGxtc' 1]
# [nan 3 1 'IM_9o9d8MJYLTwpJSC']
# [nan 1 3 'IM_0kVDHpzAR3gMutE']
# [nan 1 'IM_9yr15wey45273nw' 3]
# [nan 3 1 'IM_9sfqLb06QBgx0b4']
# [nan 1 'IM_77Ll7tk9eGKUWlE' 3]
# [nan 1 3 'IM_3mlAuhwjf65T6wm']
# [nan 3 1 'IM_5bupItZ8rB3CcIe']
# [nan 'IM_cJjcFz8HZ5kpkFM' 3 1]
# [nan 1 3 'IM_aacHgSSJ8SpHgQS']
# [nan 'IM_9H4EoaPNkdi3cAS' 3 1]
# [nan 'IM_9zXdTIKXUek7YCq' 3 1]
# [nan 1 'IM_d5L0mbRZEVGHSzc' 3]
# [nan 1 3 'IM_8uJIu79kF2DDVga']

# %%
t_list = ['IM_cC15sUM3wdS0qGO',
'IM_4YZShV208PsmCMu',
'IM_bpXACllyeiwpR78',
'IM_5C1focehBmaxTiS',
'IM_3VIIMJClBmsGxtc',
'IM_9o9d8MJYLTwpJSC',
'IM_0kVDHpzAR3gMutE',
'IM_9yr15wey45273nw',
'IM_9sfqLb06QBgx0b4',
'IM_77Ll7tk9eGKUWlE',
'IM_3mlAuhwjf65T6wm',
'IM_5bupItZ8rB3CcIe',
'IM_cJjcFz8HZ5kpkFM',
'IM_aacHgSSJ8SpHgQS',
'IM_9H4EoaPNkdi3cAS',
'IM_9zXdTIKXUek7YCq',
'IM_d5L0mbRZEVGHSzc',
'IM_8uJIu79kF2DDVga']

# %%
for i in q_list:
    for j in t_list:
        df[i] = df[i].replace(j,2)

# %%
df.head()
# Out:
#                     Q2.17 Q40.1 Q41.1 Q42.1 Q43.1 Q44.1 Q45.1  Q46.1  Q47.1  \
# 2                     NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3                     NaN   NaN   NaN   NaN     1   NaN   NaN    NaN    NaN
# 4  I don't purchase books     1   NaN   NaN   NaN   NaN   NaN    NaN    3.0
# 5            I buy ebooks   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 6              I buy both   NaN   NaN     3   NaN   NaN   NaN    2.0    NaN
#
#    Q48.1  ...  Q54.1  Q55.1  Q56.1  Q57.1  Q58.1  Q59.1  Q60.1  Q61.1  Q62.1  \
# 2    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    1.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    1.0
# 4    NaN  ...    NaN    1.0    NaN    NaN    NaN    1.0    NaN    NaN    NaN
# 5    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6    NaN  ...    NaN    NaN    1.0    NaN    NaN    NaN    NaN    NaN    1.0
#
#    Q63.1
# 2    NaN
# 3    NaN
# 4    NaN
# ...

# %%
for i in q_list:
    df[i] = df[i].replace('1',1)
    df[i] = df[i].replace('2',2)
    df[i] = df[i].replace('3',3)

# %%
df.head()
# Out:
#                     Q2.17  Q40.1  Q41.1  Q42.1  Q43.1  Q44.1  Q45.1  Q46.1  \
# 2                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                     NaN    NaN    NaN    NaN    1.0    NaN    NaN    NaN
# 4  I don't purchase books    1.0    NaN    NaN    NaN    NaN    NaN    NaN
# 5            I buy ebooks    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6              I buy both    NaN    NaN    3.0    NaN    NaN    NaN    2.0
#
#    Q47.1  Q48.1  ...  Q54.1  Q55.1  Q56.1  Q57.1  Q58.1  Q59.1  Q60.1  Q61.1  \
# 2    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    1.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    3.0    NaN  ...    NaN    1.0    NaN    NaN    NaN    1.0    NaN    NaN
# 5    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6    NaN    NaN  ...    NaN    NaN    1.0    NaN    NaN    NaN    NaN    NaN
#
#    Q62.1  Q63.1
# 2    NaN    NaN
# 3    1.0    NaN
# ...

# %%
df2 = pd.DataFrame(columns = q_list)

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Q40.1, Q41.1, Q42.1, Q43.1, Q44.1, Q45.1, Q46.1, Q47.1, Q48.1, Q49.1, Q50.1, Q51.1, Q52.1, Q53.1, Q54.1, Q55.1, Q56.1, Q57.1, Q58.1, Q59.1, Q60.1, Q61.1, Q62.1, Q63.1]
# Index: []
#
# [0 rows x 24 columns]

# %%
list1 = []
list2 = []
list3 = []
for i in q_list:
    count1 = 0
    count2 = 0
    count3 = 0
    for a in df[i]: 
        if a == 1:
            count1 += 1
        if a == 2:
            count2 += 1
        if a == 3:
            count3 += 1
    
    list1.append(count1)
    list2.append(count2)
    list3.append(count3)

# %%
a_series = pd.Series(list1, index = df2.columns)
df2 = df2.append(a_series, ignore_index=True)

# %%
a_series = pd.Series(list2, index = df2.columns)
df2 = df2.append(a_series, ignore_index=True)
a_series = pd.Series(list3, index = df2.columns)
df2 = df2.append(a_series, ignore_index=True)

# %%
df2
# Out:
#   Q40.1 Q41.1 Q42.1 Q43.1 Q44.1 Q45.1 Q46.1 Q47.1 Q48.1 Q49.1  ... Q54.1  \
# 0    15    21     9    24    17    18    26    27    23    24  ...    14
# 1    17    15    22    18    16    16    20    18    28    24  ...    33
# 2    22    17    24    13    21    20     7    10     4     6  ...    13
#
#   Q55.1 Q56.1 Q57.1 Q58.1 Q59.1 Q60.1 Q61.1 Q62.1 Q63.1
# 0    17    17    15    12    15    10    21    22    19
# 1    27    23    20    26    21    23    23    22    17
# 2    10    16    16    11    16    18    21    12    16
#
# [3 rows x 24 columns]

# %%
df2.to_csv('data.csv')
